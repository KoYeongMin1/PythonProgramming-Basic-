# %% [markdown]
# #### 참고 교재
# * "난생처음 파이썬 프로그래밍" 우재남, 최민아 저, 한빛아카데미
# * "파이썬 자습서", https://docs.python.org/ko/3/tutorial/index.html
# * "문제해결을 위한 컴퓨팅 사고와 파이썬", 김지연 저, 한빛아카데미
# #
# # 조건문
# #

# %% [markdown]
# #### 팝콘 1개 가격이 5,000원일 때 팝콘 주문 수량을 입력받아 총 주문금액을 출력하는 코드를 작성해보세요

# %%
# Out:
# 팝콘 주문 수량 : 3
# 총 주문 금액 :  15000

# %% [markdown]
# - 위와 같이 일반적인 프로그램은 명령어들이 위에서 아래로 순차적으로 실행됨

# %% [markdown]
# #### 팝콘 1개 가격이 5,000원이지만, 2개 이상 구매시 개당 가격이 4,000원인 경우 주문 수량을 입력받아 총 주문금액을 출력해보세요

# %%
# Out:
# 팝콘 주문 수량 : 1
# 총 주문 금액 :  5000

# %%
# Out:
# 팝콘 주문 수량 : 3
# 총 주문 금액 :  12000

# %% [markdown]
# - 위와 같은 경우 순차적인 명령어들로 프로그램을 구현하기 어려움

# %% [markdown]
# ### 제어구조
# - 프로그램에서 해야 할 동작의 흐름이나 순서를 처리하는 방법

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# - 프로그램에서 명령어를 선택하여 실행할 수 있게 하기위한 방법으로 "조건문" 이 있음
# #

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #
# #
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #
# #
# ## 영화 "타짜" 대사 중 조건을 사용한 상황
# #### 고니(조승우) 와 정마담(김혜수)이 팀을 이뤄 도박에서 큰 돈을 따내려는 장면
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #
# #
# ## - 조건의 정의 :
# ### 어떠한 일을 진행되게 하거나 성립되게 하기 위하여 갖추어야만 할 요소
# #### (조건은 원하는 것을 얻기 위해 먼저 갖춰줘야 하는 것을 의미함)
# ###
# #### 타짜 대사를 조건의 정의에 맞춰 생각해보자 :
# ##
# #### - 갖추어야만 하는 요소(조건) ->
# ###
# #### - 원하는 일 ->

# %% [markdown]
# #
# #
# ## - 조건을 사용하는 목적 :
# ### "조건을 정의하는 주체가 원하는 환경으로 제어하기 위함"

# %% [markdown]
# #
# #
# ## - 우리 삶에서 조건을 사용하는 경우:
# #### * 조건을 정의하는 주체와 원하는 목적 관점으로 생각해보자
# ####
# #### 1. 엄마가 아이들에게 약을 먹일 때: "약을 먹으면 사탕을 주겠다"
# ![image-7.png](attachment:image-7.png)
# #
# #### 2. 대학생이 아이패드가 필요해서 부모님께 말하는 상황 : "학점 평균 4.0 이상 받으면 아이패드 사주세요"
# #
# #
# #
# #### 3. 졸업 후 취업 연봉협상 : "연봉 5천 이상 주면 내가 회사에 2억 매출 내주겠다"
# #

# %% [markdown]
# #
# #
# ## * 조건의 목적은 원하는 환경으로 제어하기 위함임
# ## 컴퓨터에게도 프로그래머가 원하는 환경으로 제어하고자 조건문을 사용함
# ![image.png](attachment:image.png)

# %% [markdown]
# #
# #
# ## - 프로그래밍에서 조건문의 정의 :
# ![image-2.png](attachment:image-2.png)
# ### 프로그래밍에서 조건문이란 어떤 조건이 주어질 때 어떤 동작을 수행하도록 하는, 즉 조건에 따라 실행이 달라지게 할 때 사용되는 문장이다.
# ### 프로그래머가 명시한 불 또는 불린(Boolean) 데이터형 조건이 "참(True)"인지 "거짓(False)"인지에 따라 달라지는 계산이나 상황을 수행하는 프로그래밍 언어의 특징이다.
# #
# ![image.png](attachment:image.png)
# #### 프로그래밍 조건문 변환 연습

# %% [markdown]
# #
# #### 1. "약을 먹으면 사탕을 준다" 라는 문장을 프로그래밍 조건문으로 변환하면
# ![image-5.png](attachment:image-5.png)
# ####
# #### 2.  "학점 평균 4.0 이상 받으면 아이패드 사주세요" 라는 문장을 프로그래밍 조건문으로 변환하면
# ![image-6.png](attachment:image-6.png)
# ####
# #### 3. "연봉 5천 이상 주면 내가 회사에 2억 매출 내주겠다" 라는 문장을 프로그래밍 조건문으로 변환하면
# #
# #

# %% [markdown]
# #
# #
# #### 4. "운전면허 필기시험 점수가 70점 이상이면 합격, 그렇지 않으면 불합격" 라는 문장을 프로그래밍 조건문으로 변환하면
# #
# #
# #
# #
# #### 5. 현재 시간은 밤10시 입니다. 19세 미만 청소년들은 밤 10시 이후 pc방 이용이 금지됩니다. 나이를 물어보고 청소년인지, 성인인지 구분하여 청소년이면 pc방 퇴장을, 성인이면 pc방 이용을 계속하라는 문장을 조건문으로 변환해보세요
# #
# #
# #
# #
# #### 6. 키가 180cm 가 넘고, 몸무게가 80kg 이하이면 모델, 그렇지 않으면 일반인 이라는 문장을 조건문으로 변환해보세요
# #
# #
# #
# #
# #### 7. 시험성적 조건으로 등급이 결정되는 표를 조건문으로 변환해보세요
# ![image.png](attachment:image.png)
# #
# #
# #
# #
# #
# #
# #
